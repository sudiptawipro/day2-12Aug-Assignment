# %% [markdown]
# ### 1) String Slices â A way to refer to sub-parts of sequences -- typically strings and lists. The slice string[start:end] is the elements beginning at start and extending up to but not including end.
#
#      For example
#      string = "AcadGild"
#      print(string[1:4])
#      Output = cad

# %%
#Initialize string 
string = "AcadGild"

#print first 3 alphabets
print(***)

#print all alphabets but first 3
print(***)

#print the whole string using â:â
print(***)

#print all but first alphabet
print(***)
# Out:
# Aca
# dGild
# AcadGild
# cadGild

# %%
a = "AcadGild"

print(a[0:3])
print(a[3:])
print(a[:])
print(a[1:])
# Out:
# Aca
# dGild
# AcadGild
# cadGild

# %% [markdown]
# ### 2) Print the number of words and characters from a string
#
#        For Example
#        string = "Welcome to AcadGild"
#        Number of words in the string:
#        3
#        Number of characters in the string:
#        19

# %%
#Initialize string
string="Welcome to AcadGild"

#initialize char=0 to count number of characters 
char=0 

#initialize word=1 to count number of words
***

#to iterate over string
for i in string:
  #count number of characters,increment char by 1
      ***
    #check for white space to count words
      if(i==' '):
        ***
        
#print  total number of words
print("Number of words in the string:")
print(word)

#print total number of characters
print("Number of characters in the string:")
print(char)
# Out:
# Number of words in the string:
# 3
# Number of characters in the string:
# 19

# %%
my_string="Welcome to AcadGild"
print("Number of words in the string : {word}".format(word=len(my_string.split())))

x=0
y=0
for i in my_string:
    x=x+1
    if not i.isspace():
        y=y+1

print("Number of char in the string including space: {a}".format(a=x))
print("Number of char in the string  exclusing space: {b}".format(b=y))
# Out:
# Number of words in the string : 3
# Number of char including space: 19
# Number of char exclusing space: 17

# %% [markdown]
# ### 3) Print the number of vowels present in a string
#
#         For Example
#         string = "Welcome to AcadGild"
#
#         Expected Output:
#         7

# %%
#Print the number of vowels present in a string

#Initialize string
string = "Welcome to AcadGild"

#Initialize counter variable to count the number of vowels
vowels = 0

#iterate over string
for i in ***:

      #Check for the vowels âa,e,i,o,uâ in the strin
      if(***):
        #If vowels present, increase counter variable âvowelsâ by 1
        vowels += 1
         
#print the total number of vowels
print("Number of vowels are:")
print(vowels)
# Out:
# Number of vowels are:
# 7

# %%
my_string="Welcome to AcadGild"
v = ['a','e','i','o','u','A','E','I','O','U']
x = 0

for i in my_string:
    if i in v:
        x = x + 1
    
print("Number of vowels in the string: {a}".format(a=x))
# Out:
# Number of vowels in the string: 7

# %% [markdown]
# ### 4) Print a string in reverse order
#
#         For Example
#         string = "Acadgild"
#
#         Expected Output
#         d
#         l
#         i
#         g
#         d
#         a
#         c
#         A

# %%
#initialize string
string="AcadGild"


#iterate over string and reverse the string using âreversedâ function
for i in reversed(string):

#print reverse of string
    print(i, end = "")
# Out:
# dliGdacA

# %%
my_string="AcadGild"
my_string[::-1]
# Out:
# 'dliGdacA'
